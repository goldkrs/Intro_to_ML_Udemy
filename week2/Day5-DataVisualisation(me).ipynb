# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.Univariate Analysis - One variable
# 2.Bivariate Analysis - Two variables
# 3.Multivariate Analysis - Many variables

# %%
# Univariate Analysis - One variable

# %%
# Histogram

# %%
np.random.seed(1)
samples = np.random.randint(1,100,50);
plt.hist(samples,color = "red")
# Out:
# (array([10.,  7.,  5.,  3.,  1.,  3.,  4.,  8.,  4.,  5.]),
#  array([ 1. , 10.6, 20.2, 29.8, 39.4, 49. , 58.6, 68.2, 77.8, 87.4, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
np.random.seed(1)
samples = np.random.randint(1,100,50);
print(samples)
sns.histplot(x = samples)
# Out:
# [38 13 73 10 76  6 80 65 17  2 77 72  7 26 51 21 19 85 12 29 30 15 51 69
#  88 88 95 97 87 14 10  8 64 62 23 58  2  1 61 82  9 89 14 48 73 31 72  4
#  71 22]
# <Axes: ylabel='Count'>

# %%
# Pie Chart
slices =[100,60,90,70,20]
labels = ["A","B","C","D","E"]
cols = ["red","blue","#123456","orange","green"]
plt.pie(slices,labels = labels,colors = cols)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b76059aaf50>,
# ...
#  [Text(0.6628980661753352, 0.877818975564439, 'A'),
#   Text(-0.8129098762855618, 0.7410651341396334, 'B'),
#   Text(-0.8778188514344314, -0.6628982305500112, 'C'),
#   Text(0.5790755671688081, -0.9352387328955765, 'D'),
#   Text(1.081270452092701, -0.20212424256196018, 'E')])

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x=tips['sex']);

# %%
sns.countplot(x=tips['smoker']);

# %%
sns.countplot(x=tips['day']);

# %%
sns.countplot(x=tips['sex'],hue = tips["smoker"]);

# %%
plt.title("Gender Count for different days",fontsize=10,color="red")
sns.countplot(x=tips['sex'],hue = tips["day"]);

# %%
# Bivariate Analysis - Two variables

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.plot(x,y);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
sns.lineplot(x=x,y=y);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.scatter(x,y);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.scatter(x,y,s=100);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.scatter(x,y,s=100,marker="*");

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
sns.scatterplot(x=x,y=y,s=100);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.scatter(x,y,s=100);
plt.plot(x,y,linestyle='dotted',linewidth="3");

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
sns.pointplot(x=x,y=y);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
sns.pointplot(x=x,y=y,linestyles='dotted');

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
plt.bar(x,y,color=["red","orange","blue"]);

# %%
x = [1,2,3,4,5]
y = [20,30,40,100,60]
sns.barplot(x=x,y=y);

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip']);

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],s=100,hue=tips["sex"]);

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],s=100,hue=tips["smoker"]);

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],s=100,hue=tips["day"]);

# %%
sns.pointplot(x=tips['total_bill'],y=tips['tip'],hue=tips["day"]);

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],s=100,hue=tips["day"],col_wrap=4,col=tips["day"]);

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'],hue=tips["day"],col_wrap=4,col=tips["day"],kind="line");

# %%
# Joint plot = Histogram + Scatter

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'])

# %%
sns.jointplot(x=tips['total_bill'],y=tips['tip'],kind="reg")

# %%
# Heatmap

# %%
np.random.seed(1)
samples = np.random.randint(1,100,(10,10))
sns.heatmap(samples,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(samples,annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
#Multivariate Analysis

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
a = sns.PairGrid(tips)
a.map_diag(sns.histplot)
a.map_offdiag(sns.scatterplot)

# %%
x = [200,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,
     10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,
     10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,10,250,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,
     10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22,10,20,30,40,30,20,10,30,4,45,33,55,33,44,22,55,22]

# %%
sns.boxplot(x=x)
# Out:
# <Axes: >

# %%
sns.boxplot(x=tips['total_bill']);

# %%
sns.boxplot(x=tips['tip']);
